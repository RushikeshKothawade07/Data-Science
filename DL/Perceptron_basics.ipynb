# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Types of Neural Networks

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Perceptron

# %% [markdown]
# 1. is a algorithm
# 2. Used for supervised learning
# 3. or called a mathematical model/function
# 4.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Perceptron demo

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x=df['cgpa'],y=df['resume_score'],hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
p.fit(X,Y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
# !pip install --upgrade mlxtend
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
plot_decision_regions(X.values, Y.values, clf=p, legend=2)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-766ebdaf70ef> in <cell line: 1>()
# ----> 1 plot_decision_regions(X.values, Y.values, clf=p, legend=2)
#
# /usr/local/lib/python3.9/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242     colors = [next(colors_gen) for c in range(n_classes)]
#     243
# --> 244     # Get minimum and maximum
#     245     x_min, x_max = (
#     246         X[:, x_index].min() - 1.0 / zoom_factor,
#
# ...

# %%
from mlxtend.plotting import plot_decision_regions

# %%
# plot_decision_regions(X.values, Y.values, clf=p, legend=2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Problems with Perceptron

# %% [markdown]
# 1. Sometimes it may not give convergence
# 2. You cannot quatify the result like which line is better
# 3. It is a jugaad
# 4. So use Loss Function to quatify the results
