# %% [markdown]
# Calculating the likelihood of a event to occur

# %% [markdown]
# #Loss Function

# %% [markdown]
# Loss function  helps us to find the distance between the predicted value adn the original value

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Types of Distributions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Normal Distribution is also called as Gaussian Distribution / Bell shaped Curve

# %% [markdown]
# #SKEWNESS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Poissons Distribution

# %% [markdown]
# ![image.png](data:image/png;base64,...)
