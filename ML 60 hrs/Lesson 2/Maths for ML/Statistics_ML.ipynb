# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Statistics is a tool that helps us to extract information and knowledge from data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #handling missing values

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Measures of variability

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Percentile and Quartile

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Correlation and Causation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Hypothesis Testing

# %% [markdown]
# ![image.png](data:image/png;base64,...)
